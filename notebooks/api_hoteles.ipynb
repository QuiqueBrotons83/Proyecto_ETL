# %%
# Cargamos librerias
import numpy as np
import pandas as pd
import requests

# %%
# Llamamos a la url de la api con fecha del 1 al 2 de marzo.

url = "https://datos.madrid.es/egob/catalogo/300107-0-agenda-actividades-eventos.json"

# %%
# Ahora hacemos el Get

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
datos = response.json()
datos.keys()
# Out:
# dict_keys(['@context', '@graph'])

# %%
eventos = datos.get("@graph", "error")

# %%
datos.get("@graph", "error")[0]
# Out:
# {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/evento/12677513-25-aniversario-revista-fragua.json',
#  '@type': 'https://datos.madrid.es/egob/kos/actividades/Exposiciones',
#  'id': '12677513',
#  'title': '25º aniversario de la revista La Fragua',
#  'description': '',
#  'free': 1,
#  'price': '',
#  'dtstart': '2025-02-24 00:00:00.0',
#  'dtend': '2025-03-02 23:59:00.0',
#  'time': '',
#  'excluded-days': '',
#  'recurrence': {'days': 'MO,TU,WE,TH,FR,SA,SU',
#   'frequency': 'WEEKLY',
#   'interval': 1},
#  'uid': '12677513',
#  'link': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1ea220bed10d4910VgnVCM2000001f4a900aRCRD',
#  'event-location': 'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#  'references': {'@id': ''},
#  'relation': {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/5975465-biblioteca-publica-municipal-ivan-vargas-centro-.json'},
#  'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Centro'},
#   'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Centro/Barrio/Palacio',
#    'locality': 'MADRID',
#    'postal-code': '28005',
#    'street-address': 'CALLE SAN JUSTO 5'}},
#  'location': {'latitude': 40.41410290844665, 'longitude': -3.7098591212735883},
#  'organization': {'organization-name': 'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#   'accesibility': '1,6'}}

# %%
datos.get('@graph')[0].keys()
# Out:
# dict_keys(['@id', '@type', 'id', 'title', 'description', 'free', 'price', 'dtstart', 'dtend', 'time', 'excluded-days', 'recurrence', 'uid', 'link', 'event-location', 'references', 'relation', 'address', 'location', 'organization'])

# %%
dicc_api = {
      "nombre_evento" : [],
      "url_evento": [],
     "codigo_postal": [],
      "direccion": [],
      "horario": [],
      "organizacion": [],
      "fecha_inicio": [],
      "fecha_fin": []  
  }
for i in datos.get('@graph', []):
    dicc_api["nombre_evento"].append(i.get('title', np.nan))
    dicc_api["url_evento"].append(i.get('link', np.nan))
    dicc_api["codigo_postal"].append(i.get('address', {}).get('area', {}).get('postal-code', np.nan))
    dicc_api["direccion"].append(i.get('address', {}).get('area', {}).get('street-address', np.nan))
    dicc_api["horario"].append(i.get('time', np.nan))
    dicc_api["organizacion"].append(i.get('organization', {}).get('organization-name', np.nan))
    dicc_api["fecha_inicio"].append(i.get('dtstart', np.nan))
    dicc_api["fecha_fin"].append(i.get('dtend', np.nan))

# %%
df_api = pd.DataFrame(dicc_api)
df_api["hora_fecha_inicio"] = df_api["fecha_inicio"].apply(lambda x: x.split(" ")[1])
df_api["fecha_inicio"] = df_api["fecha_inicio"].apply(lambda x: x.split(" ")[0])
df_api["hora_fecha_fin"] = df_api["fecha_fin"].apply(lambda x: x.split(" ")[1])
df_api["fecha_fin"] = df_api["fecha_fin"].apply(lambda x: x.split(" ")[0])
df_api
# Out:
#                                           nombre_evento  \
# 0               25º aniversario de la revista La Fragua
# 1                                               3CLONWS
# 2          60 Premio Reina Sofía de Pintura y Escultura
# 3                                       7 pares de pies
# 4                                           A la fresca
# ...                                                 ...
# 1254  «Secretos de belleza (interior): amistad, ritu...
# 1255                      ¿Café o GinTonic? - Moratalaz
# 1256  ¿Hablamos de leyes? Especial Día de la Igualda...
# 1257                             ¿Hay vida en el metro?
# 1258                      Ça Marche 'Trabajos forzados'
#
#                                              url_evento codigo_postal  \
# 0     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28005
# 1     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28012
# 2     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28009
# 3     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28037
# 4     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28045
# ...                                                 ...           ...
# 1254  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28015
# 1255  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28030
# 1256  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28039
# 1257  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28031
# 1258  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28015
#
#                         direccion horario  \
# 0               CALLE SAN JUSTO 5
# 1                 RONDA ATOCHA 35   19:00
# 2                PASEO COLOMBIA 1
# 3     CALLE SAN ROMAN DEL VALLE 8   12:00
# 4                PASEO CHOPERA 14
# ...                           ...     ...
# 1254          CALLE CONDE DUQUE 9
# 1255        AVENIDA MORATALAZ 130   19:00
# 1256      CALLE BRAVO MURILLO 133   11:00
# 1257        CALLE MANUEL VELEZ 10
# 1258          CALLE CONDE DUQUE 9   20:00
#
#                                            organizacion fecha_inicio  \
# 0     Biblioteca Pública Municipal Iván de Vargas (C...   2025-02-24
# 1                                    Teatro Circo Price   2025-03-21
# 2                Centro Cultural Casa de Vacas (Retiro)   2025-02-27
# 3     Centro Cultural Antonio Machado (San Blas - Ca...   2025-03-23
# 4     Nave 10 Matadero. Creación Dramática Contempor...   2025-02-06
# ...                                                 ...          ...
# 1254        Centro de Cultura Contemporánea Conde Duque   2025-04-29
# 1255              Centro Cultural el Torito (Moratalaz)   2025-03-08
# 1256       Espacio de Igualdad Hermanas Mirabal. Tetuán   2025-02-21
# 1257  Centro Sociocultural Francisco Fatou (Villa de...   2024-12-16
# 1258        Centro de Cultura Contemporánea Conde Duque   2025-05-07
#
#        fecha_fin hora_fecha_inicio hora_fecha_fin
# 0     2025-03-02        00:00:00.0     23:59:00.0
# 1     2025-03-22        19:00:00.0     23:59:00.0
# 2     2025-03-23        00:00:00.0     23:59:00.0
# 3     2025-03-23        12:00:00.0     23:59:00.0
# 4     2025-02-23        00:00:00.0     23:59:00.0
# ...          ...               ...            ...
# 1254  2025-04-29        00:00:00.0     23:59:00.0
# 1255  2025-03-08        19:00:00.0     23:59:00.0
# 1256  2025-02-21        11:00:00.0     23:59:00.0
# 1257  2025-02-27        00:00:00.0     23:59:00.0
# 1258  2025-05-07        20:00:00.0     23:59:00.0
#
# [1259 rows x 10 columns]

# %%
# La función al completo sería la siguiente
def eventos_api(url):
    response = requests.get(url)
    if response.status_code == 200:
        datos = response.json()

        dicc_api = {
                "nombre_evento" : [],
                "url_evento": [],
                "codigo_postal": [],
                "direccion": [],
                "horario": [],
                "organizacion": [],
                "fecha_inicio": [],
                "fecha_fin": []  
                }

        for i in datos.get('@graph', []):
            dicc_api["nombre_evento"].append(i.get('title', np.nan))
            dicc_api["url_evento"].append(i.get('link', np.nan))
            dicc_api["codigo_postal"].append(i.get('address', {}).get('area', {}).get('postal-code', np.nan))
            dicc_api["direccion"].append(i.get('address', {}).get('area', {}).get('street-address', np.nan))
            dicc_api["horario"].append(i.get('time', np.nan))
            dicc_api["organizacion"].append(i.get('organization', {}).get('organization-name', np.nan))
            dicc_api["fecha_inicio"].append(i.get('dtstart', np.nan))
            dicc_api["fecha_fin"].append(i.get('dtend', np.nan)) 
            
    df_api = pd.DataFrame(dicc_api)
    df_api["hora_fecha_inicio"] = df_api["fecha_inicio"].apply(lambda x: x.split(" ")[1])
    df_api["fecha_inicio"] = df_api["fecha_inicio"].apply(lambda x: x.split(" ")[0])
    df_api["hora_fecha_fin"] = df_api["fecha_fin"].apply(lambda x: x.split(" ")[1])
    df_api["fecha_fin"] = df["fecha_fin"].apply(lambda x: x.split(" ")[0])
    return df_api[(df_api["fecha_inicio"] <= '2025-03-01') & (df_api["fecha_fin"] >= '2025-03-02')]
df_api
# Out:
#                                           nombre_evento  \
# 0               25º aniversario de la revista La Fragua
# 1                                               3CLONWS
# 2          60 Premio Reina Sofía de Pintura y Escultura
# 3                                       7 pares de pies
# 4                                           A la fresca
# ...                                                 ...
# 1254  «Secretos de belleza (interior): amistad, ritu...
# 1255                      ¿Café o GinTonic? - Moratalaz
# 1256  ¿Hablamos de leyes? Especial Día de la Igualda...
# 1257                             ¿Hay vida en el metro?
# 1258                      Ça Marche 'Trabajos forzados'
#
#                                              url_evento codigo_postal  \
# 0     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28005
# 1     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28012
# 2     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28009
# 3     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28037
# 4     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28045
# ...                                                 ...           ...
# 1254  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28015
# 1255  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28030
# 1256  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28039
# 1257  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28031
# 1258  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28015
#
#                         direccion horario  \
# 0               CALLE SAN JUSTO 5
# 1                 RONDA ATOCHA 35   19:00
# 2                PASEO COLOMBIA 1
# 3     CALLE SAN ROMAN DEL VALLE 8   12:00
# 4                PASEO CHOPERA 14
# ...                           ...     ...
# 1254          CALLE CONDE DUQUE 9
# 1255        AVENIDA MORATALAZ 130   19:00
# 1256      CALLE BRAVO MURILLO 133   11:00
# 1257        CALLE MANUEL VELEZ 10
# 1258          CALLE CONDE DUQUE 9   20:00
#
#                                            organizacion fecha_inicio  \
# 0     Biblioteca Pública Municipal Iván de Vargas (C...   2025-02-24
# 1                                    Teatro Circo Price   2025-03-21
# 2                Centro Cultural Casa de Vacas (Retiro)   2025-02-27
# 3     Centro Cultural Antonio Machado (San Blas - Ca...   2025-03-23
# 4     Nave 10 Matadero. Creación Dramática Contempor...   2025-02-06
# ...                                                 ...          ...
# 1254        Centro de Cultura Contemporánea Conde Duque   2025-04-29
# 1255              Centro Cultural el Torito (Moratalaz)   2025-03-08
# 1256       Espacio de Igualdad Hermanas Mirabal. Tetuán   2025-02-21
# 1257  Centro Sociocultural Francisco Fatou (Villa de...   2024-12-16
# 1258        Centro de Cultura Contemporánea Conde Duque   2025-05-07
#
#        fecha_fin hora_fecha_inicio hora_fecha_fin
# 0     2025-03-02        00:00:00.0     23:59:00.0
# 1     2025-03-22        19:00:00.0     23:59:00.0
# 2     2025-03-23        00:00:00.0     23:59:00.0
# 3     2025-03-23        12:00:00.0     23:59:00.0
# 4     2025-02-23        00:00:00.0     23:59:00.0
# ...          ...               ...            ...
# 1254  2025-04-29        00:00:00.0     23:59:00.0
# 1255  2025-03-08        19:00:00.0     23:59:00.0
# 1256  2025-02-21        11:00:00.0     23:59:00.0
# 1257  2025-02-27        00:00:00.0     23:59:00.0
# 1258  2025-05-07        20:00:00.0     23:59:00.0
#
# [1259 rows x 10 columns]

# %%
df_api
# Out:
#                                           nombre_evento  \
# 0               25º aniversario de la revista La Fragua
# 1                                               3CLONWS
# 2          60 Premio Reina Sofía de Pintura y Escultura
# 3                                       7 pares de pies
# 4                                           A la fresca
# ...                                                 ...
# 1254  «Secretos de belleza (interior): amistad, ritu...
# 1255                      ¿Café o GinTonic? - Moratalaz
# 1256  ¿Hablamos de leyes? Especial Día de la Igualda...
# 1257                             ¿Hay vida en el metro?
# 1258                      Ça Marche 'Trabajos forzados'
#
#                                              url_evento codigo_postal  \
# 0     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28005
# 1     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28012
# 2     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28009
# 3     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28037
# 4     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28045
# ...                                                 ...           ...
# 1254  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28015
# 1255  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28030
# 1256  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28039
# 1257  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28031
# 1258  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28015
#
#                         direccion horario  \
# 0               CALLE SAN JUSTO 5
# 1                 RONDA ATOCHA 35   19:00
# 2                PASEO COLOMBIA 1
# 3     CALLE SAN ROMAN DEL VALLE 8   12:00
# 4                PASEO CHOPERA 14
# ...                           ...     ...
# 1254          CALLE CONDE DUQUE 9
# 1255        AVENIDA MORATALAZ 130   19:00
# 1256      CALLE BRAVO MURILLO 133   11:00
# 1257        CALLE MANUEL VELEZ 10
# 1258          CALLE CONDE DUQUE 9   20:00
#
#                                            organizacion fecha_inicio  \
# 0     Biblioteca Pública Municipal Iván de Vargas (C...   2025-02-24
# 1                                    Teatro Circo Price   2025-03-21
# 2                Centro Cultural Casa de Vacas (Retiro)   2025-02-27
# 3     Centro Cultural Antonio Machado (San Blas - Ca...   2025-03-23
# 4     Nave 10 Matadero. Creación Dramática Contempor...   2025-02-06
# ...                                                 ...          ...
# 1254        Centro de Cultura Contemporánea Conde Duque   2025-04-29
# 1255              Centro Cultural el Torito (Moratalaz)   2025-03-08
# 1256       Espacio de Igualdad Hermanas Mirabal. Tetuán   2025-02-21
# 1257  Centro Sociocultural Francisco Fatou (Villa de...   2024-12-16
# 1258        Centro de Cultura Contemporánea Conde Duque   2025-05-07
#
#        fecha_fin hora_fecha_inicio hora_fecha_fin
# 0     2025-03-02        00:00:00.0     23:59:00.0
# 1     2025-03-22        19:00:00.0     23:59:00.0
# 2     2025-03-23        00:00:00.0     23:59:00.0
# 3     2025-03-23        12:00:00.0     23:59:00.0
# 4     2025-02-23        00:00:00.0     23:59:00.0
# ...          ...               ...            ...
# 1254  2025-04-29        00:00:00.0     23:59:00.0
# 1255  2025-03-08        19:00:00.0     23:59:00.0
# 1256  2025-02-21        11:00:00.0     23:59:00.0
# 1257  2025-02-27        00:00:00.0     23:59:00.0
# 1258  2025-05-07        20:00:00.0     23:59:00.0
#
# [1259 rows x 10 columns]

# %%
df_api[(df_api["fecha_inicio"] <= '2025-03-01') & (df_api["fecha_fin"] >= '2025-03-02')]
# Out:
#                                      nombre_evento  \
# 0          25º aniversario de la revista La Fragua
# 2     60 Premio Reina Sofía de Pintura y Escultura
# 6                                      A toda vela
# 10       Acompañamiento digital a personas mayores
# 11                         Acompañar en la pérdida
# ...                                            ...
# 1145                           Y tú, ¿cómo viajas?
# 1149                    Yoga para el buen trato II
# 1163                  'Clases de árabe para niños'
# 1226                'Refugiados' por Myriam Laguía
# 1243         ¡Ahora nos toca jugar! Juegos de mesa
#
#                                              url_evento codigo_postal  \
# 0     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28005
# 2     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28009
# 6     http://www.madrid.es/sites/v/index.jsp?vgnextc...         28045
# 10    http://www.madrid.es/sites/v/index.jsp?vgnextc...           NaN
# 11    http://www.madrid.es/sites/v/index.jsp?vgnextc...         28029
# ...                                                 ...           ...
# 1145  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28037
# 1149  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28045
# 1163  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28041
# 1226  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28019
# 1243  http://www.madrid.es/sites/v/index.jsp?vgnextc...         28043
#
#                               direccion horario  \
# 0                     CALLE SAN JUSTO 5
# 2                      PASEO COLOMBIA 1
# 6                       PLAZA LEGAZPI 8
# 10                                  NaN
# 11         AVENIDA MONFORTE DE LEMOS 38   17:00
# ...                                 ...     ...
# 1145  CALLE HERMANOS GARCIA NOBLEJAS 14   10:00
# 1149                   PASEO CHOPERA 10   18:00
# 1163              AVENIDA SAN FERMIN 10   18:00
# 1226              CALLE ISAAC ALBENIZ 1   19:00
# 1243               CALLE MATAPOZUELOS 2   11:00
#
#                                            organizacion fecha_inicio  \
# 0     Biblioteca Pública Municipal Iván de Vargas (C...   2025-02-24
# 2                Centro Cultural Casa de Vacas (Retiro)   2025-02-27
# 6                                       Matadero Madrid   2024-10-01
# 10                                                  NaN   2024-10-14
# 11    Biblioteca Pública Municipal José Saramago (Fu...   2025-01-14
# ...                                                 ...          ...
# 1145  Biblioteca Pública Municipal Ciudad Lineal (Ci...   2024-12-04
# 1149         Espacio de Igualdad Juana Doña. Arganzuela   2025-02-18
# 1163    Biblioteca Pública Municipal San Fermín (Usera)   2024-12-13
# 1226  Biblioteca Pública Municipal Ana María Matute ...   2025-02-14
# 1243        Espacio de Igualdad Carme Chacón. Hortaleza   2025-01-03
#
#        fecha_fin hora_fecha_inicio hora_fecha_fin
# 0     2025-03-02        00:00:00.0     23:59:00.0
# 2     2025-03-23        00:00:00.0     23:59:00.0
# 6     2025-06-01        00:00:00.0     23:59:00.0
# 10    2025-06-30        00:00:00.0     23:59:00.0
# 11    2025-06-17        17:00:00.0     23:59:00.0
# ...          ...               ...            ...
# 1145  2025-05-28        10:00:00.0     23:59:00.0
# 1149  2025-03-11        18:00:00.0     23:59:00.0
# 1163  2025-05-30        18:00:00.0     23:59:00.0
# 1226  2025-03-13        19:00:00.0     23:59:00.0
# 1243  2025-03-28        11:00:00.0     23:59:00.0
#
# [217 rows x 10 columns]

# %%
# Guardamos el dataframe en un csv
df_api.to_csv("../data/datos_eventos.csv", index = False)
